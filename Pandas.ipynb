# %% [markdown]
# A Pandas series is a one-dimensional array-like object that can hold many data types, such as numbers or strings. One of the main differences between Pandas Series and NumPy ndarrays is that you can assign an index label to each element in the Pandas Series. In other words, you can name the indices of your Pandas Series anything you want. Another big difference between Pandas Series and NumPy ndarrays is that Pandas Series can hold data of different data types.

# %%
# pd is the standard alias
import pandas as pd

# %%
# A panda series is a 1-dimentional array-like object, that can hold many data types.
# You can assign an index label to each element in the Series
groceries = pd.Series(data=[30, 6, 'yes', 'no'], index=['eggs', 'apples', 'milk', 'bread'])
groceries
# Out:
# eggs       30
# apples      6
# milk      yes
# bread      no
# dtype: object

# %%
# View properties of the Series
groceries.shape
# Out:
# (4,)

# %%
groceries.ndim
# Out:
# 1

# %%
groceries.size
# Out:
# 4

# %%
groceries.index
# Out:
# Index(['eggs', 'apples', 'milk', 'bread'], dtype='object')

# %%
groceries.values
# Out:
# array([30, 6, 'yes', 'no'], dtype=object)

# %%
'banana' in groceries
# Out:
# False

# %%
'bread' in groceries
# Out:
# True

# %% [markdown]
# One great advantage of Pandas Series is that it allows us to access data in many different ways. Elements can be accessed using index labels or numerical indices inside square brackets, [ ], similar to how we access elements in NumPy ndarrays. Since we can use numerical indices, we can use both positive and negative integers to access data from the beginning or from the end of the Series, respectively. Since we can access elements in various ways, in order to remove any ambiguity to whether we are referring to an index label or numerical index, Pandas Series have two attributes, .loc and .iloc to explicitly state what we mean. The attribute .loc stands for location and it is used to explicitly state that we are using a labeled index. Similarly, the attribute .iloc stands for integer location and it is used to explicitly state that we are using a numerical index.

# %%
groceries
# Out:
# eggs       30
# apples      6
# milk      yes
# bread      no
# dtype: object

# %%
groceries['eggs']
# Out:
# 30

# %%
## can specify a LIST of index labels (list is inside square brackets)
groceries[['milk','bread']]
# Out:
# milk     yes
# bread     no
# dtype: object

# %%
groceries[0]
# Out:
# 30

# %%
groceries[-1]
# Out:
# 'no'

# %%
# .loc for labelled index, .iloc for integer index
groceries.loc['eggs']
# Out:
# 30

# %%
groceries.iloc[[0,3]]
# Out:
# eggs     30
# bread    no
# dtype: object

# %%
# drop apples out of place
groceries.drop('apples')
# Out:
# eggs      30
# milk     yes
# bread     no
# dtype: object

# %%
# drop apples in place
groceries.drop('apples', inplace=True)
groceries
# Out:
# eggs      30
# milk     yes
# bread     no
# dtype: object

# %% [markdown]
# Just like with NumPy ndarrays, we can perform element-wise arithmetic operations on Pandas Series. In this lesson we will look at arithmetic operations between Pandas Series and single numbers. Let's create a new Pandas Series that will hold a grocery list of just fruits.

# %%
fruits = pd.Series([10, 6, 3],['apples','oranges','bananas'])
fruits
# Out:
# apples     10
# oranges     6
# bananas     3
# dtype: int64

# %%
fruits * 2
# Out:
# apples     20
# oranges    12
# bananas     6
# dtype: int64

# %%
fruits / 2
# Out:
# apples     5.0
# oranges    3.0
# bananas    1.5
# dtype: float64

# %% [markdown]
# You can also apply mathematical functions from NumPy, such as sqrt(x), to all elements of a Pandas Series.

# %%
import numpy as np
np.power(fruits, 2)
# Out:
# apples     100
# oranges     36
# bananas      9
# dtype: int64

# %%
fruits['bananas'] + 2
# Out:
# 5

# %%
fruits.iloc[0] - 2
# Out:
# 8

# %%
fruits.loc[['bananas','apples']] * 2
# Out:
# bananas     6
# apples     20
# dtype: int64

# %% [markdown]
# You can also apply arithmetic operations on Pandas Series of mixed data type provided that the arithmetic operation is defined for all data types in the Series, otherwise you will get an error. Let's see what happens when we multiply our grocery list by 2

# %%
fruits = pd.Series([1,2,3,'Yes','No'])
print(fruits)
print(fruits * 2)
# Out:
# 0      1
# 1      2
# 2      3
# 3    Yes
# 4     No
# dtype: object
# 0         2
# 1         4
# 2         6
# 3    YesYes
# 4      NoNo
# dtype: object

# %% [markdown]
# Quiz

# %%
distance_from_sun = [149.6, 1433.5, 227.9, 108.2, 778.6]

planets = ['Earth','Saturn', 'Mars','Venus', 'Jupiter']

# %%
planet_distances = pd.Series(distance_from_sun,planets)
print(planet_distances)
# Out:
# Earth       149.6
# Saturn     1433.5
# Mars        227.9
# Venus       108.2
# Jupiter     778.6
# dtype: float64

# %%
planet_times = planet_distances / 18
print(planet_times)
# Out:
# Earth       8.311111
# Saturn     79.638889
# Mars       12.661111
# Venus       6.011111
# Jupiter    43.255556
# dtype: float64

# %%
planet_times[planet_times < 40]
# Out:
# Earth     8.311111
# Mars     12.661111
# Venus     6.011111
# dtype: float64

# %% [markdown]
# Pandas DataFrames are two-dimensional data structures with labeled rows and columns, that can hold many data types. If you are familiar with Excel, you can think of Pandas DataFrames as being similar to a spreadsheet. We can create Pandas DataFrames manually or by loading data from a file. In these lessons we will start by learning how to create Pandas DataFrames manually from dictionaries and later we will see how we can load data into a DataFrame from a data file.
#
# We will start by creating a DataFrame manually from a dictionary of Pandas Series. In this case the first step is to create the dictionary of Pandas Series. After the dictionary is created we can then pass the dictionary to the pd.DataFrame() function.
#
# We will create a dictionary that contains items purchased by two people, Alice and Bob, on an online store. The Pandas Series will use the price of the items purchased as data, and the purchased items will be used as the index labels to the Pandas Series.

# %%
items = {'Bob':pd.Series([123,412,34],['bike','pants','watch']) , 'Alice':pd.Series([645,23,43],['bike','pants','glasses'])}
print(items)
# Out:
# {'Bob': bike     123
# pants    412
# watch     34
# dtype: int64, 'Alice': bike       645
# pants       23
# glasses     43
# dtype: int64}

# %%
shopping_carts = pd.DataFrame(items)
shopping_carts
# Out:
#            Bob  Alice
# bike     123.0  645.0
# glasses    NaN   43.0
# pants    412.0   23.0
# watch     34.0    NaN

# %%
shopping_carts.values
# Out:
# array([[123., 645.],
#        [ nan,  43.],
#        [412.,  23.],
#        [ 34.,  nan]])

# %%
shopping_carts.ndim
# Out:
# 2

# %% [markdown]
# There might be cases when you are only interested in a subset of the data. Pandas allows us to select which data we want to put into our DataFrame by means of the keywords columns and index. Let's see some examples:

# %%
pd.DataFrame(shopping_carts, index=['bike','pants'])
# Out:
#          Bob  Alice
# bike   123.0  645.0
# pants  412.0   23.0

# %%
pd.DataFrame(shopping_carts, columns=['Bob'])
# Out:
#            Bob
# bike     123.0
# glasses    NaN
# pants    412.0
# watch     34.0

# %% [markdown]
# You can also manually create DataFrames from a dictionary of lists (arrays). The procedure is the same as before, we start by creating the dictionary and then passing the dictionary to the pd.DataFrame() function. In this case, however, all the lists (arrays) in the dictionary must be of the same length. Notice that since the data dictionary we created doesn't have label indices, Pandas automatically uses numerical row indexes when it creates the DataFrame. We can however, put labels to the row index by using the index keyword in the pd.DataFrame() function. Let's see an example

# %%
data = {'ints':[1,2,3],'floats':[1.4,4.2,5.1]}
data
# Out:
# {'ints': [1, 2, 3], 'floats': [1.4, 4.2, 5.1]}

# %%
pd.DataFrame(data)
# Out:
#    ints  floats
# 0     1     1.4
# 1     2     4.2
# 2     3     5.1

# %%
pd.DataFrame(data, index=['row1','row2','row3'])
# Out:
#       ints  floats
# row1     1     1.4
# row2     2     4.2
# row3     3     5.1

# %% [markdown]
# We can access elements in Pandas DataFrames in many different ways. In general, we can access rows, columns, or individual elements of the DataFrame by using the row and column labels. We will use the same store_items DataFrame created in the previous lesson. Let's see some examples:

# %%
items = [{'bikes':20, 'pants':30, 'watches':50},{'watches':10, 'bikes':60, 'glasses':10}]
items
# Out:
# [{'bikes': 20, 'pants': 30, 'watches': 50},
#  {'watches': 10, 'bikes': 60, 'glasses': 10}]

# %%
import pandas as pd
store_items = pd.DataFrame(items)
store_items
# Out:
#    bikes  pants  watches  glasses
# 0     20   30.0       50      NaN
# 1     60    NaN       10     10.0

# %% [markdown]
# access a column by column name (must be a list, i.e. inside square brackets)

# %%
store_items[['bikes']]
# Out:
#    bikes
# 0     20
# 1     60

# %%
store_items[['bikes','pants']]
# Out:
#    bikes  pants
# 0     20   30.0
# 1     60    NaN

# %% [markdown]
# access a row by index using .loc

# %%
store_items.loc[[0]]
# Out:
#    bikes  pants  watches  glasses
# 0     20   30.0       50      NaN

# %% [markdown]
# access individual elements of the dataframe by referencing column then row

# %%
store_items['bikes'][0]
# Out:
# 20

# %% [markdown]
# adding new column

# %%
store_items['shirts'] = [0,1]
store_items
# Out:
#    bikes  pants  watches  glasses  shirts
# 0     20   30.0       50      NaN       0
# 1     60    NaN       10     10.0       1

# %% [markdown]
# ##
# Dealing with Missing Values

# %%
## count the number of NaN values
store_items.isnull().sum().sum()
# Out:
# 2

# %%
## drop rows with NaN values
store_items.dropna(axis=0)
# Out:
# Empty DataFrame
# Columns: [bikes, pants, watches, glasses, shirts]
# Index: []

# %%
## drop columns with NaN values
store_items.dropna(axis=1)
# Out:
#    bikes  watches  shirts
# 0     20       50       0
# 1     60       10       1

# %%
## replace NaN values with 0
store_items.fillna(0)
# Out:
#    bikes  pants  watches  glasses  shirts
# 0     20   30.0       50      0.0       0
# 1     60    0.0       10     10.0       1

# %%
## forward fill NaN values
store_items.ffill()
# Out:
#    bikes  pants  watches  glasses  shirts
# 0     20   30.0       50      NaN       0
# 1     60   30.0       10     10.0       1

# %%
## interpolate the NaN values
store_items.interpolate(method='linear', axis=1)
# Out:
#    bikes  pants  watches  glasses  shirts
# 0   20.0   30.0     50.0     25.0     0.0
# 1   60.0   35.0     10.0     10.0     1.0

# %% [markdown]
# Loading CSVs

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\colli_000\Documents\Python
# ['.git', '.ipynb_checkpoints', 'Attractions.csv', 'Pandas.ipynb']

# %%
myData = pd.read_csv('./Attractions.csv')
myData.head()
# Out:
#                               Name  \
# 0                     Thomond Park
# 1  Ireland Writing Retreat Donegal
# 2                    Swords Castle
# 3                 Kilbolane Castle
# 4     Cathedral of Christ the King
#
#                                                  Url         Telephone  \
# 0                          http://www.thomondpark.ie       35361421109
# 1              https://www.irelandwritingretreat.com      353833000000
# 2                       https://swordscastle.events/  +353(0)1840 0891
# 3  https://visitballyhoura.com/explore/kilbolane-...        3536391300
# 4                      http://www.mullingarparish.ie      353449000000
#
#    Longitude   Latitude AddressRegion AddressLocality       AddressCountry  \
# 0  -8.642519  52.674216      Limerick             NaN              Ireland
# 1  -8.232855  55.051496       Donegal        Gweedore              Ireland
# 2  -6.220338  53.459928        Dublin          Swords  Republic of Ireland
# 3  -8.846867  52.337725          Cork             NaN              Ireland
# 4  -7.345811  53.527051     Westmeath       Mullingar              Ireland
#
#                                                 Tags
# 0  Museums and Attraction,Stadium,Sports Venue,Ve...
# 1        Learning,Activity Operator,Literary Ireland
# 2             Historic Houses and Castle,Castle,Tour
# 3                  Historic Houses and Castle,Castle
# 4  Historic Houses and Castle,Church Abbey,Monast...

# %%
myData[['Url']]
# Out:
#                                                    Url
# 0                            http://www.thomondpark.ie
# 1                https://www.irelandwritingretreat.com
# 2                         https://swordscastle.events/
# 3    https://visitballyhoura.com/explore/kilbolane-...
# 4                        http://www.mullingarparish.ie
# ..                                                 ...
# 921                                                NaN
# 922          https://www.coillte.ie/site/careys-castle
# 923                                                NaN
# 924                                                NaN
# 925                    http://www.blueflagireland.org/
#
# [926 rows x 1 columns]

# %%
myData['Url'][1]
# Out:
# 'https://www.irelandwritingretreat.com'

# %%
## check if any null values
myData.isnull().any()
# Out:
# Name               False
# Url                 True
# Telephone           True
# Longitude          False
# Latitude           False
# AddressRegion       True
# AddressLocality     True
# AddressCountry      True
# Tags               False
# dtype: bool

# %%
myData.describe()
# Out:
#         Longitude    Latitude
# count  926.000000  926.000000
# mean    -7.764196   52.956265
# std      1.369202    0.834195
# min    -10.462682   51.433008
# 25%     -8.978143   52.290229
# 50%     -7.540516   52.962816
# 75%     -6.353320   53.375944
# max     -6.030845   55.258608
